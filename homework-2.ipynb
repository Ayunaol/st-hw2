# %%
import matplotlib.pyplot as plt
import numpy as np
import pylab

from mpl_toolkits.mplot3d import Axes3D
from matplotlib import cm
from matplotlib.ticker import LinearLocator, FormatStrFormatter
from scipy.misc import derivative, electrocardiogram
from scipy.optimize import minimize, approx_fprime, fmin, brute
from scipy.signal import find_peaks

# %matplotlib inline

# %% [markdown]
# ### Задание 1

# %% [markdown]
# Придумайте функции со следующими свойствами (в a) b) c) область определения X любая, какая вам удобна, главное - функция с нужными свойствами):
#
# a) бесконечное количество локальных экстремумов
#
# b) 2 локальных экстремума
#
# с) 3 локальных экстремума
#
# d*) область определения функции - 1 точка

# %%
#a
def f(x):
    return np.sin(x)
# objective function

x = np.linspace(-15,15,100)
y = f(x)
pylab.plot(x,y)
pylab.show()

# %%
#b
def f(x):
    return x ** 2 + 10 / x
x = np.linspace(-15,15,100)
y = f(x)
pylab.plot(x,y)
pylab.show()

# %%
#c
def f(x):
    return x ** 2 + 10 / x ** 2
x = np.linspace(-15,15,100)
y = f(x)
pylab.plot(x,y)
pylab.show()

# %% [markdown]
# ### Задание 2

# %% [markdown]
# Посчитайте 1-ую и 2-ую производные функции (на бумажке):
#
# $f(x) = sin^2(2x+1)$

# %%
from PIL import Image
img = Image.open("23.JPEG")
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1280x718 at 0x10C9CF25D30>

# %% [markdown]
# ### Задание 3:
# Посчитайте частные производные функции в точкe
# (на бумажке или в LaTeX и на numpy):

# %% [markdown]
# $f(x,y)=2x^2y^3 + 1/x + y^2x + 7$ в точке $(1,2)$

# %%
def func(x, c0, c1):
    "Coordinate vector `x` should be an array of size two."
    return c0 * x[0]**2 * x[1]**3 + 1 / x[0] + c1 * x[1]**2 * x[0] + 7

# %%
x = np.array([1, 2])
c0, c1 = (2, 1)
eps = np.sqrt(np.finfo(float).eps)
approx_fprime(x, func, [eps, eps], c0, c1)
# Out:
# array([35.00000024, 28.00000024])

# %% [markdown]
# ### Задание 4:
#
# Градиентный спуск своими руками

# %%
def f(x):
    return (x[0]**2) + (x[1]**2)

# %%
x = np.array([100, 200])
lr = 0.1

# %%
eps = np.sqrt(np.finfo(float).eps)
for i in range(100):
    # Calculate gradient
    grad = approx_fprime(x, f, [eps, eps]) # Your code here (функция для вычисления градиента есть в лекционном ноутбуке)
    
    # Update x with gradient
    x = x - lr * grad # Your code here (смотри слайд презентации про градиентный спуск)

# %%
print("Минимум достигается в: ", x)
print("Значение функции в минимуме: ", f(x))
# Out:
# Минимум достигается в:  [-7.45058060e-09 -7.45058062e-09]
# Значение функции в минимуме:  1.1102230275973354e-16

# %% [markdown]
# Проверка с помощью встроенной функции numpy:

# %%
res = minimize(f, [100, 200], method='nelder-mead', options={'xtol': 1e-6, 'disp': True})
# Out:
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 72
#          Function evaluations: 138
